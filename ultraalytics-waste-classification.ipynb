# %%
from ultralytics import YOLO

# Load a model
# model = YOLO('yolov8n-cls.yaml')  # build a new model from YAML
# model = YOLO('yolov8n-cls.pt')  # load a pretrained model (recommended for training)
model = YOLO('yolov8n-cls.yaml').load('yolov8n-cls.pt')  # build from YAML and transfer weights

# Train the model
results = model.train(data='ds/', epochs=100, imgsz=64)
# Out:
# YOLOv8n-cls summary: 99 layers, 2719288 parameters, 2719288 gradients, 4.4 GFLOPs
# Transferred 158/158 items from pretrained weights
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.8 torch-2.2.1+cpu CPU (AMD Ryzen 7 4800H with Radeon Graphics)
# engine\trainer: task=classify, mode=train, model=yolov8n-cls.yaml, data=ds/, epochs=100, time=None, patience=100, batch=16, imgsz=64, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\classify\train3
# train: C:\Ashu\projects\PBL_Stage1\ds\train... found 164333 images in 2 classes ✅
# val: None...
# test: C:\Ashu\projects\PBL_Stage1\ds\test... found 20440 images in 2 classes ✅
# Overriding model.yaml nc=1000 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    332802  ultralytics.nn.modules.head.Classify         [256, 2]
# YOLOv8n-cls summary: 99 layers, 1440850 parameters, 1440850 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs\classify\train3', view at http://localhost:6006/
# train: Scanning C:\Ashu\projects\PBL_Stage1\ds\train... 164331 images, 2 corrupt: 100%|██████████| 164331/164331 [00:00
# train: WARNING ⚠️ C:\Ashu\projects\PBL_Stage1\ds\train\Dry\00000006 - Copy.jpg: ignoring corrupt image/label: image file is truncated (4 bytes not processed)
# train: WARNING ⚠️ C:\Ashu\projects\PBL_Stage1\ds\train\Dry\00000006.jpg: ignoring corrupt image/label: image file is truncated (4 bytes not processed)
# train: WARNING ⚠️ C:\Ashu\projects\PBL_Stage1\ds\train\Waste\00000021.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ C:\Ashu\projects\PBL_Stage1\ds\train\Waste\1_332.jpg: corrupt JPEG restored and saved
# val: Scanning C:\Ashu\projects\PBL_Stage1\ds\test... 20439 images, 1 corrupt: 100%|██████████| 20439/20439 [00:00<?, ?i
# val: WARNING ⚠️ C:\Ashu\projects\PBL_Stage1\ds\test\Dry\00000261.jpg: ignoring corrupt image/label: image file is truncated (19 bytes not processed)
# val: WARNING ⚠️ C:\Ashu\projects\PBL_Stage1\ds\test\Waste\00000226.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ C:\Ashu\projects\PBL_Stage1\ds\test\Waste\00000279.jpg: corrupt JPEG restored and saved
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 64 train, 64 val
# Using 0 dataloader workers
# Logging results to runs\classify\train3
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100         0G     0.3101         11         64: 100%|██████████| 10271/10271 [18:55<00:00,  9.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [01:03<00:00, 10.08it/s]
#                    all      0.885          1
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100         0G     0.2398         11         64: 100%|██████████| 10271/10271 [15:38<00:00, 10.95it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:45<00:00, 13.94it/s]
#                    all      0.881          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100         0G     0.2481         11         64: 100%|██████████| 10271/10271 [15:21<00:00, 11.15it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:45<00:00, 13.92it/s]
#                    all      0.871          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100         0G      0.253         11         64: 100%|██████████| 10271/10271 [15:25<00:00, 11.10it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:49<00:00, 12.99it/s]
#                    all       0.87          1
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100         0G     0.2289         11         64: 100%|██████████| 10271/10271 [15:35<00:00, 10.97it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:47<00:00, 13.52it/s]
#                    all      0.872          1
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100         0G     0.2215         11         64: 100%|██████████| 10271/10271 [15:22<00:00, 11.13it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:46<00:00, 13.81it/s]
#                    all      0.875          1
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100         0G      0.221         11         64: 100%|██████████| 10271/10271 [15:21<00:00, 11.14it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:46<00:00, 13.81it/s]
#                    all      0.878          1
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100         0G     0.2215         11         64: 100%|██████████| 10271/10271 [15:24<00:00, 11.11it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:46<00:00, 13.79it/s]
#                    all      0.878          1
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100         0G     0.2213         11         64: 100%|██████████| 10271/10271 [15:30<00:00, 11.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:47<00:00, 13.40it/s]
#                    all      0.877          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100         0G     0.2209         11         64: 100%|██████████| 10271/10271 [15:30<00:00, 11.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:46<00:00, 13.79it/s]
#                    all      0.876          1
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100         0G     0.2211         11         64: 100%|██████████| 10271/10271 [15:28<00:00, 11.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:46<00:00, 13.79it/s]
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100         0G     0.2198         11         64: 100%|██████████| 10271/10271 [15:27<00:00, 11.07it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:46<00:00, 13.71it/s]
#                    all      0.874          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100         0G     0.2193         11         64: 100%|██████████| 10271/10271 [15:35<00:00, 10.97it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:47<00:00, 13
1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      77/100         0G     0.1716         11         64: 100%|██████████| 10271/10271 [16:37<00:00, 10.29it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:50<00:00, 12.56it/s]
#                    all      0.893          1
#       Epoch    GPU_mem       loss  Instances       Size
#      78/100         0G     0.1705         11         64: 100%|██████████| 10271/10271 [16:44<00:00, 10.22it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:52<00:00, 12.21it/s]
#                    all      0.893          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      79/100         0G     0.1696         11         64: 100%|██████████| 10271/10271 [16:39<00:00, 10.27it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:51<00:00, 12.47it/s]
#                    all      0.894          1
#       Epoch    GPU_mem       loss  Instances       Size
#      89/100         0G     0.1558         11         64: 100%|██████████| 10271/10271 [18:32<00:00,  9.23it/s]
#      91/100         0G     0.1509         11         64: 100%|██████████| 10271/10271 [33:26<00:00,  5.12it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [01:11<00:00,  8.90it/s]
#                    all      0.896          1
#       Epoch    GPU_mem       loss  Instances       Size
#      92/100         0G     0.1505         11         64: 100%|██████████| 10271/10271 [18:39<00:00,  9.17it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:51<00:00, 12.40it/s]
#                    all      0.897          1
#       Epoch    GPU_mem       loss  Instances       Size
#      93/100         0G       0.15         11         64: 100%|██████████| 10271/10271 [16:42<00:00, 10.25it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:53<00:00, 12.05it/s]
#                    all      0.897          1
#       Epoch    GPU_mem       loss  Instances       Size
#      94/100         0G     0.1459         11         64: 100%|██████████| 10271/10271 [16:42<00:00, 10.24it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:51<00:00, 12.39it/s]
#                    all      0.897          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      95/100         0G     0.1445         11         64: 100%|██████████| 10271/10271 [16:34<00:00, 10.32it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:50<00:00, 12.57it/s]
#                    all      0.898          1
#       Epoch    GPU_mem       loss  Instances       Size
#      96/100         0G     0.1427         11         64: 100%|██████████| 10271/10271 [16:36<00:00, 10.31it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:50<00:00, 12.58it/s]
#                    all      0.898          1
#       Epoch    GPU_mem       loss  Instances       Size
#      97/100         0G     0.1398         11         64: 100%|██████████| 10271/10271 [16:44<00:00, 10.22it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:52<00:00, 12.21it/s]
#                    all      0.897          1
#       Epoch    GPU_mem       loss  Instances       Size
#      98/100         0G     0.1381         11         64: 100%|██████████| 10271/10271 [16:43<00:00, 10.23it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:51<00:00, 12.45it/s]
#                    all      0.897          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      99/100         0G     0.1341         11         64: 100%|██████████| 10271/10271 [16:53<00:00, 10.13it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:54<00:00, 11.73it/s]
#                    all      0.898          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     100/100         0G     0.1324         11         64: 100%|██████████| 10271/10271 [16:58<00:00, 10.08it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:51<00:00, 12.48it/s]
#                    all      0.898          1
# 100 epochs completed in 40.444 hours.
# Optimizer stripped from runs\classify\train3\weights\last.pt, 3.0MB
# Optimizer stripped from runs\classify\train3\weights\best.pt, 3.0MB
#
# Validating runs\classify\train3\weights\best.pt...
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.8 torch-2.2.1+cpu CPU (AMD Ryzen 7 4800H with Radeon Graphics)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
# train: C:\Ashu\projects\PBL_Stage1\ds\train... found 164333 images in 2 classes ✅
# val: None...
# test: C:\Ashu\projects\PBL_Stage1\ds\test... found 20440 images in 2 classes ✅
#                classes   top1_acc   top5_acc: 100%|██████████| 639/639 [00:50<00:00, 12.69it/s]
#                    all      0.899          1
# Speed: 0.0ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs\classify\train3
# Results saved to runs\classify\train3

# %%
from ultralytics import YOLO
import cv2

model = YOLO('runs/classify/train3/weights/best.pt')

video = cv2.VideoCapture(0)  # Read the video file
if not video.isOpened():
    print("Cannot open camera")
    exit()
while True:
    ret, frame = video.read()  # Read the video frames

    # Exit the loop if no more frames in either video
    if not ret:
        break

    # Track objects in frames if available
    results = model(frame)
    res_plotted = results[0].plot()
    cv2.imshow("Tracking_Stream_", res_plotted)

    key = cv2.waitKey(1)
    if key == ord('q'):
        break

# Release video sources
video.release()
# Out:
# 0: 64x64 Dry 0.82, Waste 0.18, 5.5ms
# Speed: 10.0ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 4.5ms
# Speed: 5.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 4.5ms
# Speed: 4.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 5.0ms
# Speed: 4.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 4.5ms
# Speed: 4.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 4.5ms
# Speed: 4.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.82, Waste 0.18, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.80, Waste 0.20, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.81, Waste 0.19, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.82, Waste 0.18, 5.0ms
# Speed: 4.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.84, Waste 0.16, 2.0ms
# Speed: 4.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.84, Waste 0.16, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.83, Waste 0.17, 4.5ms
# Speed: 3.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 2.0ms
# Speed: 4.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.84, Waste 0.16, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 4.2ms
# Speed: 2.0ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 2.0ms
# Speed: 4.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 2.0ms
# Speed: 4.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.77, Waste 0.23, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 2.0ms
# Speed: 3.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.76, Waste 0.24, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.72, Waste 0.28, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.74, Waste 0.26, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.77, Waste 0.23, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.70, Waste 0.30, 5.0ms
# Speed: 3.5ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.70, Waste 0.30, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.71, Waste 0.29, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.73, Waste 0.27, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.68, Waste 0.32, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.74, Waste 0.26, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.70, Waste 0.30, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.69, Waste 0.31, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.73, Waste 0.27, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.72, Waste 0.28, 4.5ms
# Speed: 4.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.77, Waste 0.23, 2.0ms
# Speed: 4.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.79, Waste 0.21, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.78, Waste 0.22, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.71, Waste 0.29, 2.0ms
# Speed: 4.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.69, Waste 0.31, 2.0ms
# Speed: 4.0ms preprocess, 2.0ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.74, Waste 0.26, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.74, Waste 0.26, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.80, Waste 0.20, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.71, Waste 0.29, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.76, Waste 0.24, 3.5ms
# Speed: 2.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.78, Waste 0.22, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.78, Waste 0.22, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.80, Waste 0.20, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 2.0ms
# Speed: 3.0ms preprocess, 2.0ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.74, Waste 0.26, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.76, Waste 0.24, 3.0ms
# Speed: 2.5ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.80, Waste 0.20, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.71, Waste 0.29, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.77, Waste 0.23, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.72, Waste 0.28, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.78, Waste 0.22, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.70, Waste 0.30, 2.0ms
# Speed: 4.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.70, Waste 0.30, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.68, Waste 0.32, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.63, Waste 0.37, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.65, Waste 0.35, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.69, Waste 0.31, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.67, Waste 0.33, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.66, Waste 0.34, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.76, Waste 0.24, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.71, Waste 0.29, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.72, Waste 0.28, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.73, Waste 0.27, 2.0ms
# Speed: 3.5ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.76, Waste 0.24, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.82, Waste 0.18, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.83, Waste 0.17, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.70, Waste 0.30, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.78, Waste 0.22, 3.5ms
# Speed: 4.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.84, Waste 0.16, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 2.5ms
# Speed: 3.0ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.76, Waste 0.24, 3.0ms
# Speed: 5.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 2.0ms
# Speed: 4.0ms preprocess, 2.0ms inference, 1.5ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 2.0ms
# Speed: 4.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 2.0ms
# Speed: 3.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.84, Waste 0.16, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.83, Waste 0.17, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 4.5ms
# Speed: 3.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.83, Waste 0.17, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.83, Waste 0.17, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.81, Waste 0.19, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.83, Waste 0.17, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.83, Waste 0.17, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.84, Waste 0.16, 4.5ms
# Speed: 5.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.84, Waste 0.16, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 2.0ms
# Speed: 3.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 2.0ms
# Speed: 3.0ms preprocess, 2.0ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 3.0ms
# Speed: 5.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 2.0ms
# Speed: 3.5ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.84, Waste 0.16, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 3.5ms
# Speed: 4.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.83, Waste 0.17, 2.0ms
# Speed: 4.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.83, Waste 0.17, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.84, Waste 0.16, 3.5ms
# Speed: 2.5ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.84, Waste 0.16, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.82, Waste 0.18, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.83, Waste 0.17, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.78, Waste 0.22, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.76, Waste 0.24, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.78, Waste 0.22, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.81, Waste 0.19, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.83, Waste 0.17, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.67, Waste 0.33, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.60, Waste 0.40, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.66, Waste 0.34, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.67, Waste 0.33, 2.0ms
# Speed: 3.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.62, Waste 0.38, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.66, Waste 0.34, 2.5ms
# Speed: 3.0ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.68, Waste 0.32, 3.5ms
# Speed: 4.5ms preprocess, 3.5ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.68, Waste 0.32, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.68, Waste 0.32, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.70, Waste 0.30, 3.5ms
# Speed: 2.5ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.64, Waste 0.36, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.76, Waste 0.24, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.73, Waste 0.27, 3.5ms
# Speed: 4.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.73, Waste 0.27, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.64, Waste 0.36, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.78, Waste 0.22, 3.0ms
# Speed: 3.6ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.80, Waste 0.20, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.80, Waste 0.20, 3.0ms
# Speed: 5.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.72, Waste 0.28, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.83, Waste 0.17, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 4.0ms
# Speed: 3.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 4.3ms
# Speed: 4.0ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 2.0ms
# Speed: 3.5ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.79, Waste 0.21, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.80, Waste 0.20, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.68, Waste 0.32, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.94, Waste 0.06, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 3.2ms
# Speed: 4.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.80, Waste 0.20, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.65, Waste 0.35, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.94, Waste 0.06, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 2.5ms
# Speed: 3.0ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 3.5ms
# Speed: 2.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.93, Waste 0.07, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.94, Waste 0.06, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 4.0ms
# Speed: 3.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.97, Waste 0.03, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.96, Waste 0.04, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.96, Waste 0.04, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.94, Waste 0.06, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.96, Waste 0.04, 3.6ms
# Speed: 2.0ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.96, Waste 0.04, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.97, Waste 0.03, 5.0ms
# Speed: 5.5ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.94, Waste 0.06, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.96, Waste 0.04, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.96, Waste 0.04, 3.5ms
# Speed: 4.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.97, Waste 0.03, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.96, Waste 0.04, 3.0ms
# Speed: 2.8ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.97, Waste 0.03, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.96, Waste 0.04, 2.5ms
# Speed: 4.0ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.96, Waste 0.04, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 3.5ms
# Speed: 4.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.66, Waste 0.34, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.74, Dry 0.26, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.68, Dry 0.32, 4.0ms
# Speed: 3.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.88, Dry 0.12, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.89, Dry 0.11, 3.5ms
# Speed: 4.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.90, Dry 0.10, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.97, Dry 0.03, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.97, Dry 0.03, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.97, Dry 0.03, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.96, Dry 0.04, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.95, Dry 0.05, 3.0ms
# Speed: 2.5ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.99, Dry 0.01, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.96, Dry 0.04, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.99, Dry 0.01, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 5.2ms
# Speed: 3.0ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 2.6ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 2.5ms
# Speed: 3.0ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 1.00, Dry 0.00, 3.1ms
# Speed: 3.1ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.98, Dry 0.02, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.96, Dry 0.04, 3.0ms
# Speed: 3.5ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.82, Dry 0.18, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.89, Dry 0.11, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.83, Dry 0.17, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.83, Dry 0.17, 3.0ms
# Speed: 3.5ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.82, Dry 0.18, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.65, Dry 0.35, 3.0ms
# Speed: 2.5ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.81, Dry 0.19, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.98, Dry 0.02, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.98, Dry 0.02, 2.0ms
# Speed: 3.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.99, Dry 0.01, 2.0ms
# Speed: 3.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.99, Dry 0.01, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.99, Dry 0.01, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.98, Dry 0.02, 3.0ms
# Speed: 3.5ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.98, Dry 0.02, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.95, Dry 0.05, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.95, Dry 0.05, 2.0ms
# Speed: 3.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.76, Dry 0.24, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.84, Dry 0.16, 5.0ms
# Speed: 5.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.85, Dry 0.15, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.77, Dry 0.23, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.77, Dry 0.23, 4.0ms
# Speed: 2.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.67, Dry 0.33, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.76, Dry 0.24, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.75, Dry 0.25, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.75, Dry 0.25, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.68, Dry 0.32, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.65, Dry 0.35, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.65, Dry 0.35, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.55, Dry 0.45, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.53, Dry 0.47, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.83, Dry 0.17, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.75, Dry 0.25, 3.2ms
# Speed: 4.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.75, Dry 0.25, 5.0ms
# Speed: 5.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.67, Dry 0.33, 4.0ms
# Speed: 5.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.91, Dry 0.09, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.96, Dry 0.04, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.93, Dry 0.07, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.90, Dry 0.10, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.94, Dry 0.06, 4.0ms
# Speed: 5.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.94, Dry 0.06, 3.0ms
# Speed: 3.5ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.90, Dry 0.10, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.86, Dry 0.14, 4.0ms
# Speed: 3.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.84, Dry 0.16, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.86, Dry 0.14, 3.0ms
# Speed: 5.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.86, Dry 0.14, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.68, Dry 0.32, 3.1ms
# Speed: 4.1ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.66, Dry 0.34, 5.0ms
# Speed: 3.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.74, Dry 0.26, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.63, Dry 0.37, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.68, Dry 0.32, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.68, Dry 0.32, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.68, Dry 0.32, 3.5ms
# Speed: 4.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.72, Dry 0.28, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.71, Dry 0.29, 5.0ms
# Speed: 4.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.68, Dry 0.32, 2.5ms
# Speed: 4.0ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.62, Dry 0.38, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.62, Dry 0.38, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.68, Dry 0.32, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.67, Dry 0.33, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.73, Dry 0.27, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.74, Dry 0.26, 2.5ms
# Speed: 3.0ms preprocess, 2.5ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.73, Dry 0.27, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.77, Dry 0.23, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.77, Dry 0.23, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.77, Dry 0.23, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.78, Dry 0.22, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.68, Dry 0.32, 3.5ms
# Speed: 4.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.59, Dry 0.41, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.59, Dry 0.41, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.60, Dry 0.40, 4.6ms
# Speed: 3.0ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.61, Dry 0.39, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.70, Dry 0.30, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.78, Dry 0.22, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.79, Dry 0.21, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.82, Dry 0.18, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.82, Dry 0.18, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.88, Dry 0.12, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.72, Dry 0.28, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.77, Dry 0.23, 2.0ms
# Speed: 3.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.80, Dry 0.20, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.80, Dry 0.20, 3.0ms
# Speed: 4.5ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.85, Dry 0.15, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.82, Dry 0.18, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.86, Dry 0.14, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.52, Dry 0.48, 5.0ms
# Speed: 5.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.54, Dry 0.46, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.94, Waste 0.06, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.73, Waste 0.27, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 5.0ms
# Speed: 3.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.96, Waste 0.04, 3.5ms
# ...
#
# 0: 64x64 Dry 0.91, Waste 0.09, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 2.5ms
# Speed: 3.0ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 3.0ms
# Speed: 2.5ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 5.0ms
# Speed: 3.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 4.5ms
# Speed: 2.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.86, Waste 0.14, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.87, Waste 0.13, 4.0ms
# Speed: 4.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.93, Waste 0.07, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 2.5ms
# Speed: 3.0ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.93, Waste 0.07, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.93, Waste 0.07, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.93, Waste 0.07, 4.0ms
# Speed: 4.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 4.1ms
# Speed: 3.0ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.93, Waste 0.07, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.93, Waste 0.07, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.93, Waste 0.07, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.93, Waste 0.07, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.93, Waste 0.07, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.93, Waste 0.07, 5.0ms
# Speed: 5.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 2.5ms
# Speed: 3.0ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 3.2ms
# Speed: 4.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 4.0ms
# Speed: 2.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 2.5ms
# Speed: 3.0ms preprocess, 2.5ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 3.5ms
# Speed: 4.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.90, Waste 0.10, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.92, Waste 0.08, 3.0ms
# Speed: 3.2ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.94, Waste 0.06, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.96, Waste 0.04, 3.4ms
# Speed: 3.1ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.94, Waste 0.06, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.94, Waste 0.06, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.96, Waste 0.04, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.95, Waste 0.05, 3.0ms
# Speed: 5.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.93, Waste 0.07, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.93, Waste 0.07, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.91, Waste 0.09, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.84, Waste 0.16, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.82, Waste 0.18, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.83, Waste 0.17, 5.0ms
# Speed: 4.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.85, Waste 0.15, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.89, Waste 0.11, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.82, Waste 0.18, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.81, Waste 0.19, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.69, Waste 0.31, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.69, Waste 0.31, 2.0ms
# Speed: 4.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.76, Waste 0.24, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.76, Waste 0.24, 4.2ms
# Speed: 3.5ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.72, Waste 0.28, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.88, Waste 0.12, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.78, Waste 0.22, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.73, Waste 0.27, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.74, Waste 0.26, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.70, Waste 0.30, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.51, Waste 0.49, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.69, Waste 0.31, 2.5ms
# Speed: 2.0ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.62, Waste 0.38, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.79, Waste 0.21, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.76, Waste 0.24, 3.0ms
# Speed: 2.5ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.67, Waste 0.33, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.68, Waste 0.32, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.71, Waste 0.29, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.84, Waste 0.16, 4.0ms
# Speed: 3.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.73, Waste 0.27, 3.8ms
# Speed: 2.2ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 3.9ms
# Speed: 2.1ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.62, Dry 0.38, 4.0ms
# Speed: 4.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.58, Waste 0.42, 3.0ms
# Speed: 3.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Waste 0.58, Dry 0.42, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.65, Waste 0.35, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.73, Waste 0.27, 2.0ms
# Speed: 4.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.75, Waste 0.25, 4.0ms
# Speed: 3.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.80, Waste 0.20, 3.0ms
# Speed: 4.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 Dry 0.78, Waste 0.22, 2.6ms
# Speed: 4.0ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
